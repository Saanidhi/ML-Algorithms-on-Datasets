# %%
#Import the following libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt #for plotting the results

# %%
#The training and tes dataset is taken from kaggle and stored in dataset_train variable
dataset_train = pd.read_csv("/Users/saanidhi/Downloads/trainset.csv")

# %%
#displaying the contents of the training dataset
dataset_train
# Out:
#             Date         Open         High          Low        Close  \
# 0     2013-01-02   357.385559   361.151062   355.959839   359.288177
# 1     2013-01-03   360.122742   363.600128   358.031342   359.496826
# 2     2013-01-04   362.313507   368.339294   361.488861   366.600616
# 3     2013-01-07   365.348755   367.301056   362.929504   365.001007
# 4     2013-01-08   365.393463   365.771027   359.874359   364.280701
# 5     2013-01-09   363.769043   366.789398   361.945892   366.675140
# 6     2013-01-10   369.014923   370.092896   364.380066   368.344269
# 7     2013-01-11   368.602600   368.816193   365.771027   367.604095
# 8     2013-01-14   366.118744   368.701935   358.841095   359.288177
# 9     2013-01-15   357.340851   365.125214   353.749207   360.122742
# 10    2013-01-16   358.865936   359.829651   354.529144   355.284210
# 11    2013-01-17   356.536072   357.494843   353.212677   353.361725
# 12    2013-01-18   352.884827   354.082031   348.398987   349.978729
# ...

# %%
trainset = dataset_train.iloc[:,1:2].values

# %%
trainset
# Out:
# array([[  357.385559],
#        [  360.122742],
#        [  362.313507],
#        ...,
#        [ 1057.390015],
#        [ 1051.599976],
#        [ 1046.719971]])

# %%
#scaling data to the range of 0-1
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0,1))
training_scaled = sc.fit_transform(trainset)

# %%
training_scaled
# Out:
# array([[ 0.01011148],
#        [ 0.01388614],
#        [ 0.01690727],
#        ...,
#        [ 0.97543954],
#        [ 0.9674549 ],
#        [ 0.96072522]])

# %%
#declaring empty arrays
x_train = []
y_train = []

# %%
for i in range(60,1259):
    x_train.append(training_scaled[i-60:i, 0])
    y_train.append(training_scaled[i,0])
x_train,y_train = np.array(x_train),np.array(y_train)

# %%
x_train.shape
# Out:
# (1199, 60)

# %%
x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1))

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
# Out:
# Using TensorFlow backend.

# %%
regressor = Sequential()
regressor.add(LSTM(units = 50,return_sequences = True,input_shape = (x_train.shape[1],1)))

# %%
regressor.add(Dropout(0.2))

# %%
regressor.add(LSTM(units = 50,return_sequences = True))
regressor.add(Dropout(0.2))

# %%
regressor.add(LSTM(units = 50,return_sequences = True))
regressor.add(Dropout(0.2))

# %%
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))

# %%
regressor.add(Dense(units = 1))

# %%
regressor.compile(optimizer = 'adam',loss = 'mean_squared_error')

# %%
regressor.fit(x_train,y_train,epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 1199/1199 [==============================] - 13s 11ms/step - loss: 0.0375
# Epoch 2/100
# 1199/1199 [==============================] - 9s 8ms/step - loss: 0.0053
# Epoch 3/100
# 1199/1199 [==============================] - 10s 8ms/step - loss: 0.0041
# Epoch 4/100
# 1199/1199 [==============================] - 9s 7ms/step - loss: 0.0037
# Epoch 5/100
# 1199/1199 [==============================] - 9s 7ms/step - loss: 0.0036
# Epoch 6/100
# 1199/1199 [==============================] - 9s 7ms/step - loss: 0.0036
# Epoch 7/100
# 1199/1199 [==============================] - 9s 8ms/step - loss: 0.0038
# Epoch 8/100
# 1199/1199 [==============================] - 9s 8ms/step - loss: 0.0034
# Epoch 9/100
# 1199/1199 [==============================] - 9s 8ms/step - loss: 0.0033
# Epoch 10/100
# 1199/1199 [==============================] - 9s 7ms/step - loss: 0.0032
# Epoch 11/100
# 1199/1199 [==============================] - 9s 7ms/step - loss: 0.0043
# Epoch 12/100
# ...

# %%
dataset_test =pd.read_csv("/Users/saanidhi/Downloads/testset.csv")

# %%
real_stock_price = dataset_test.iloc[:,1:2].values

# %%
dataset_total = pd.concat((dataset_train['Open'],dataset_test['Open']),axis = 0)
dataset_total
# Out:
# 0       357.385559
# 1       360.122742
# 2       362.313507
# 3       365.348755
# 4       365.393463
# 5       363.769043
# 6       369.014923
# 7       368.602600
# 8       366.118744
# 9       357.340851
# 10      358.865936
# 11      356.536072
# 12      352.884827
# 13      350.053253
# 14      365.617004
# 15      368.225037
# 16      372.959259
# 17      373.451050
# 18      370.962250
# 19      374.434662
# 20      372.830109
# 21      376.650238
# 22      381.364594
# 23      378.105774
# 24      377.082428
# 25      382.363098
# 26      387.544403
# 27      386.684998
# 28      388.349152
# 29      387.544403
#           ...
# 95     1061.859985
# 96     1074.060059
# 97     1083.560059
# 98     1065.130005
# 99     1079.000000
# 100    1079.020020
# 101    1064.890015
# 102    1063.030029
# 103    1067.560059
# 104    1099.349976
# 105    1122.329956
# 106    1140.989990
# 107    1142.170044
# 108    1131.319946
# 109    1118.180054
# 110    1118.599976
# ...

# %%
inputs = dataset_total[len(dataset_total) - len(dataset_test)-60:].values
inputs
# Out:
# array([  955.48999 ,   966.700012,   980.      ,   980.      ,
#          973.719971,   987.450012,   992.      ,   992.099976,
#          990.289978,   991.77002 ,   986.      ,   989.440002,
#          989.52002 ,   970.      ,   968.369995,   980.      ,
#         1009.190002,  1014.      ,  1015.219971,  1017.210022,
#         1021.76001 ,  1022.109985,  1028.98999 ,  1027.27002 ,
#         1030.52002 ,  1033.98999 ,  1026.459961,  1023.419983,
#         1022.590027,  1019.210022,  1022.52002 ,  1034.01001 ,
#         1020.26001 ,  1023.309998,  1035.      ,  1035.869995,
#         1040.      ,  1055.089966,  1042.680054,  1022.369995,
#         1015.799988,  1012.659973,   995.940002,  1001.5     ,
#         1020.429993,  1037.48999 ,  1035.5     ,  1039.630005,
#         1046.119995,  1045.      ,  1054.609985,  1066.079956,
#         1075.199951,  1071.780029,  1064.949951,  1061.109985,
#         1058.069946,  1057.390015,  1051.599976,  1046.719971,
# ...

# %%
inputs = inputs.reshape(-1,1)

# %%
inputs
# Out:
# array([[  955.48999 ],
#        [  966.700012],
#        [  980.      ],
#        [  980.      ],
#        [  973.719971],
#        [  987.450012],
#        [  992.      ],
#        [  992.099976],
#        [  990.289978],
#        [  991.77002 ],
#        [  986.      ],
#        [  989.440002],
#        [  989.52002 ],
#        [  970.      ],
#        [  968.369995],
#        [  980.      ],
#        [ 1009.190002],
#        [ 1014.      ],
#        [ 1015.219971],
#        [ 1017.210022],
#        [ 1021.76001 ],
#        [ 1022.109985],
#        [ 1028.98999 ],
#        [ 1027.27002 ],
#        [ 1030.52002 ],
#        [ 1033.98999 ],
#        [ 1026.459961],
#        [ 1023.419983],
#        [ 1022.590027],
#        [ 1019.210022],
#        [ 1022.52002 ],
#        [ 1034.01001 ],
#        [ 1020.26001 ],
#        [ 1023.309998],
#        [ 1035.      ],
#        [ 1035.869995],
#        [ 1040.      ],
#        [ 1055.089966],
#        [ 1042.680054],
#        [ 1022.369995],
# ...

# %%
inputs = sc.transform(inputs)
inputs.shape
# Out:
# (185, 1)

# %%
x_test = []
for i in range(60,185):
    x_test.append(inputs[i-60:i,0])

# %%
x_test = np.array(x_test)
x_test.shape
# Out:
# (125, 60)

# %%
x_test = np.reshape(x_test, (x_test.shape[0],x_test.shape[1],1))
x_test.shape
# Out:
# (125, 60, 1)

# %%
predicted_price = regressor.predict(x_test)

# %%
predicted_price = sc.inverse_transform(predicted_price)
predicted_price
# Out:
# array([[ 1060.9173584 ],
#        [ 1060.00036621],
#        [ 1063.09033203],
#        [ 1072.6114502 ],
#        [ 1084.62792969],
#        [ 1095.33752441],
#        [ 1103.03845215],
#        [ 1104.54577637],
#        [ 1103.51330566],
#        [ 1101.67919922],
#        [ 1106.03137207],
#        [ 1113.11877441],
#        [ 1120.23510742],
#        [ 1125.37304688],
#        [ 1129.09375   ],
#        [ 1135.60119629],
#        [ 1146.10424805],
#        [ 1155.3067627 ],
#        [ 1161.01647949],
#        [ 1163.57971191],
#        [ 1162.7121582 ],
#        [ 1161.17785645],
#        [ 1159.28588867],
#        [ 1150.99597168],
#        [ 1135.33215332],
#        [ 1109.18884277],
#        [ 1092.73730469],
#        [ 1086.14489746],
#        [ 1079.49182129],
#        [ 1077.25170898],
#        [ 1078.22033691],
#        [ 1080.33459473],
#        [ 1086.67626953],
#        [ 1095.20703125],
#        [ 1101.75415039],
#        [ 1106.91271973],
#        [ 1111.44592285],
# ...

# %%
plt.plot(real_stock_price,color = 'red', label = 'Real Price')
plt.plot(predicted_price, color = 'blue', label = 'Predicted Price')
plt.title('Google Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()
